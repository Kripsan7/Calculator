# %%
## #wap to input text and count the number of vowels and consonants
 text = input("Enter a text: ").lower()
 count_vowels = 0
 count_consonants = 0
 for i in text:
     if i.isalpha():
         if i == 'a' or i == 'e' or i == 'i' or i == 'o' or i == 'u':
            count_vowels += 1
        else: 
            count_consonants += 1

print(f"The number of vowels is {count_vowels}")
print(f"The number of consonants os {count_consonants}")

#wap to input 10 numbers and find the sum of negative and positive numbers
nums = []
negative_list = []
positive_list = []
positive_sum = 0
negative_sum = 0
for i in range(1, 11):
    number = int(input(f"Enter a number {i}: "))
    nums.append(number)
    if number >= 0:
        positive_list.append(number)
        positive_sum += number
    else:
        negative_list.append(number)
        negative_sum += number
        
print("Given numbers: ", nums)
print("Positive list: ", positive_list)
print("Negative list: ", negative_list)
print(f"Positive sum = {positive_sum}")
print(f"Negative sum = {negative_sum}")

#reverse a string
reverse = ""
last = ""
text = input("Enter a string: ")
for i in text:
    if i.isalpha():
        reverse = i + reverse

print("Reversed text: ", reverse)

#sum of digits
number = int(input("Enter a number: "))
num = number
rem = 0
total = 0
while number != 0:
    rem = number % 10
    total += rem
    number //= 10

print(f"Sum of {num}: {total}")

#Fibonacci series
a = 0 
b = 1
num = int(input("Enter the number of elements: "))

print("Fibonacci series : ")
for i in range(num):
    print(a)
    c = a+b
    a = b
    b = c

#using function
def Fibonacci(num):
    if num == 0:
        return 0
    if num == 1:
        return 1
    else:
        return Fibonacci(num-1) + Fibonacci(num-2)

n = int(input("Enter the number of elements: "))
for i in range(n):
    print(Fibonacci(i))

#sort dictionary values
values = {}
greatest = 0
for i in range(1,6):
    name = input(f"Enter student name {i}: ")
    marks = int(input(f"Enter marks {i}: "))
    values[name] = marks

items = list(values.items())

for i in range(len(items)):
    for j in range(i+1, len(items)):
        if items[i][1] > items[j][1]:   #[1] for value, [0] for key
            items[i], items[j] = items[j], items[i]

sorted_dict = dict(items)
print(sorted_dict)

#find duplicates in list
data = []
duplicate = []
for i in range(1,6):
    value = int(input(f"Enter value {i}: "))
    data.append(value)

for x in range(len(data)):
    for y in range(x+1, len(data)):
        if data[x] == data[y] not in duplicate:
            duplicate.append(data[x])
        
print("Duplicate data: ", duplicate)

#word frequency counter
paragraph = input("Enter a paragraph: ")

words = paragraph.lower().split()
word_count =  {}

for word in words:
    word = word.strip("./[]'{}(),")
    if word in word_count:
        word_count[word] += 1

    else:
        word_count[word] = 1

print("Word frequencies: ")
for word, count in word_count.items():
    print(f"{word} : {count}")

#round up or down
def round(remainder, x):
    
    if remainder < 0.5:
        print("Number rounded down.")
        x = x - remainder

    else: 
        print("Number rounded up.")
        x = x + (1 - remainder)

    return x
       
num = float(input("Enter a number with decimal point: "))
remaining = num % 1
rounded_value = round(remaining, num)
print("The final answer is: ",rounded_value)

#wap to input a mark and calculate grade using function
def grade(mark):
    if mark < 100 and mark >= 90:
         return "Grade A"
    elif mark < 90 and mark >= 85:
          return "Grade B"
    elif mark < 85 and mark >= 80:
         return "Grade C"
    elif mark < 80 and mark >= 75:
         return "Grade D"
    elif mark < 75 and mark >= 60:
        return "Grade E"
    elif mark < 60 and mark >= 0:
        return "Fail"
    else:
        return "Invalid input."

marks = float(input("Enter the mark: "))
print(grade(marks))

wap to find the sum of list of integers using function

def sum_of_list(list_x, number):
    total = 0
    for j in range(number):
       total += list_x[j]
    return total

numbers = []
num = int(input("Enter the number of integers: "))
for i in range(1, num+1):
        n = int(input(f"Enter integer {i}: "))
        numbers.append(n)
answer = sum_of_list(numbers, num)
print("Sum = ", answer)

#program to reverse a string using fuction
def reverse_string(word):
    reverse = ""
    for i in word:
        if i.isalpha():
            reverse = i + reverse
    return reverse

string = input("Enter a string: ")
print(reverse_string(string))

#wap to input a string and find number of capital letters and lowercase
def Case_counter(text):
    uprcase_count = 0
    lwrcase_count = 0
    for i in text:
        if i.isalpha():
            if i.isupper():
                uprcase_count += 1
            else:
                lwrcase_count += 1

    return uprcase_count, lwrcase_count #returns as tuple

string = input("Enter a string: ")
uc, lc = Case_counter(string)
print("No. of uppercase letters: ", uc)
print("No. of lowercase letters: ", lc)

prime number checker
def check_prime(number):
    count = 0
    if number <= 1:
        return f"{number} is not a prime number"
    if number > 1:
        for i in range(2, int(number**0.5)+1):
            if number % i == 0:
                count += 1

        if count == 0:
            return f"{number} is a prime number."
        else:
            return f"{number} isnot a prime number."

num = int(input("Enter a number: "))
print(check_prime(num))

#wap to find sum of digits of a integer
def sum_of_digits(number):
    rem = 0
    total = 0
    
    while number != 0:
        rem = number % 10
        total += rem
        number //=10

    return total

digit = int(input("Enter a number: "))
answer = sum_of_digits(digit)
print(f"Sum of {digit}: {answer}")

#List and dictionary
students = [
    {"name": "Lee" , "address": "Bharatpur", "age": 25},
    {"name": "Bee" , "address": "Bharatpur", "age": 19},
    {"name": "Tai" , "address": "Tadi", "age": 24},
    {"name": "Rei" , "address": "Parsa", "age": 28}
]
print("Student Details \n")
print("{:15} {:<15} {:<15} \n".format("Name", "Address", "Age")) 
print("*"*45 + "\n")

for std in students:
    print("{:15} {:<15} {:<15}".format(std['name'], std['address'], std['age']))

#wap to input name, address and salary of 10 employees and display them in proper format
employees = []
for i in range(1, 4):
    name = input(f"Enter name {i}: ")
    address = input(f"Enter address {i}: ")
    salary = float(input(f"Enter salary {i}: "))

    emp = {
        "name": name,
        "address": address,
        "salary": salary
    }
    employees.append(emp)

print("Employee Details \n")
print("{:15} {:<15} {:<15} \n".format("Name", "Address", "Salary"))
print("-" *38 + "\n")

for employee in employees:
    print("{:15} {:<15} {:<15}".format(employee['name'], employee['address'], employee['salary']))


with open("text.txt", "w") as f:
    f.write("Hello from other side")
    print("Success")
with open("text.txt", "r") as f:
    print(f.read())

#wap to input name, address and salary of five employees and write into an employee.txt file
employees = []
for i in range (1, 4):
    name = input(f"Enter name {i}: ")
    address = input(f"Enter address {i}: ")
    salary = float(input(f"Enter salary{i}: "))

    employee = {
        "name": name,
        "address": address,
        "salary": salary
    }
    # emp_1 = list(employee)
    employees.append(employee)


# filename = "employee.txt"
# file = open(filename, "w")
# for emp in employees:
#     file.write(emp)
#     file.close()
    
with open("employee.txt", "w") as f:
    f.write("{:15} {:<15} {:<15} \n".format("Name", "Address", "Salary"))
    for emp in employees:
        f.write("{:15} {:<15} {:<15} \n".format(emp['name'], emp['address'], emp['salary']))


print("Data stored successfully.")
    

#wap to input 5 employees details and store the employee less than 20000
employees = []
for i in range(1,3):
    name = input(f"Enter name {i}: ")
    address = input(f"Enter address {i}: ")
    salary = float(input(f"Enter salary{i}: "))

    employee = {
        "name": name,
        "address": address,
        "salary": salary
    }
    
    employees.append(employee)

with open("employee.txt", "w") as f:
    f.write("Employee details of employees whose salary is less than 20000. \n")
    f.write("{:15} {:<15} {:<15} \n".format("Name", "Address", "Salary"))
    for emp in employees: 
        if emp['salary'] < 20000:
            f.write("{:15} {:<15} {:<15} \n".format(emp['name'], emp['address'], emp['salary']))
            print(emp)

    print("Data stored successfully.")
# Out:
#   File <string>:9
#     else:
#           ^
# IndentationError: unindent does not match any outer indentation level
